# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
mydata=pd.read_csv('smartwatches.csv')
mydata.head()
# Out:
#    Unnamed: 0       Brand  Current Price  Original Price  Discount Percentage  \
# 0           0       noise        82990.0         89900.0             7.686318
# 1           1  fire-boltt         3799.0         16999.0            77.651627
# 2           2        boat         1999.0          7990.0            74.981227
# 3           3  fire-boltt         1799.0         19999.0            91.004550
# 4           4       noise         1599.0          4999.0            68.013603
#
#    Rating  Number OF Ratings                              Model Name  \
# 0     4.0               65.0   Wrb-sw-colorfitpro4alpha-std-rgld_pnk
# 1     4.3            20788.0                                  BSW046
# 2     3.8            21724.0                               Wave Call
# 3     4.3            13244.0                                  BSW053
# 4     4.1            13901.0  Wrb-sw-colorfitpulsegobuzz-std-blk_blk
#
#   Dial Shape Strap Color Strap Material Touchscreen  Battery Life (Days)  \
# ...

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           450 non-null    int64
#  1   Brand                450 non-null    object
#  2   Current Price        440 non-null    float64
#  3   Original Price       377 non-null    float64
#  4   Discount Percentage  377 non-null    float64
#  5   Rating               444 non-null    float64
#  6   Number OF Ratings    391 non-null    float64
#  7   Model Name           415 non-null    object
#  8   Dial Shape           327 non-null    object
#  9   Strap Color          327 non-null    object
#  10  Strap Material       381 non-null    object
#  11  Touchscreen          413 non-null    object
#  12  Battery Life (Days)  418 non-null    float64
#  13  Bluetooth            444 non-null    object
#  14  Display Size         420 non-null    object
# ...

# %%
mydata.describe(include='all')
# Out:
#         Unnamed: 0       Brand  Current Price  Original Price  \
# count   450.000000         450     440.000000      377.000000
# unique         NaN          18            NaN             NaN
# top            NaN  fire-boltt            NaN             NaN
# freq           NaN          60            NaN             NaN
# mean    224.500000         NaN   12747.554545    14598.204244
# std     130.048068         NaN   17760.666099    15450.028869
# min       0.000000         NaN    1199.000000     1669.000000
# 25%     112.250000         NaN    2180.750000     5999.000000
# 50%     224.500000         NaN    3999.000000     7999.000000
# 75%     336.750000         NaN   17121.750000    17999.000000
# max     449.000000         NaN  139990.000000    96390.000000
#
#         Discount Percentage      Rating  Number OF Ratings Model Name  \
# count            377.000000  444.000000         391.000000        415
# unique                  NaN         NaN                NaN        389
# ...

# %%
mydata['Brand'].max()
# Out:
# 'zebronics'

# %%
plt.figure(figsize=(10,5))
plt.title("No. of Ratings for each Brand")
sns.lineplot(data=mydata['Original Price'], label="Original Price")
sns.lineplot(data=mydata['Number OF Ratings'], label="Number OF Rating")
plt.xlabel("Brand")
# Out:
# Text(0.5, 0, 'Brand')

# %%
c=mydata.corr()
c
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11164\1103550246.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c=mydata.corr()
#                      Unnamed: 0  Current Price  Original Price  \
# Unnamed: 0             1.000000      -0.082605       -0.079370
# Current Price         -0.082605       1.000000        0.970261
# Original Price        -0.079370       0.970261        1.000000
# Discount Percentage   -0.092257      -0.627595       -0.508600
# Rating                -0.263381       0.394447        0.332426
# Number OF Ratings     -0.130883      -0.142049       -0.136846
# Battery Life (Days)    0.353799       0.025192       -0.122888
#
#                      Discount Percentage    Rating  Number OF Ratings  \
# Unnamed: 0                     -0.092257 -0.263381          -0.130883
# ...

# %%
sns.heatmap(c)
plt.show()

# %%
mydata.cov()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11164\370479986.py:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mydata.cov()
#                         Unnamed: 0  Current Price  Original Price  \
# Unnamed: 0            16912.500000  -1.903876e+05   -1.684495e+05
# Current Price       -190387.571091   3.154413e+08    2.135379e+08
# Original Price      -168449.456283   2.135379e+08    2.387034e+08
# Discount Percentage    -305.547052  -2.155414e+05   -1.894523e+05
# Rating                  -18.725535   3.833669e+03    2.798015e+03
# Number OF Ratings   -652560.728376  -1.028091e+08   -8.949582e+07
# Battery Life (Days)     344.930429   3.483341e+03   -1.438761e+04
#
#                      Discount Percentage       Rating  Number OF Ratings  \
# Unnamed: 0                   -305.547052   -18.725535      -6.525607e+05
# ...

# %%
mydata.Rating.var()
# Out:
# 0.3031034815854229
